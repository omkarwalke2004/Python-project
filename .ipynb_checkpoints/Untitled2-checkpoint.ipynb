# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\\Users\\omkar\\Downloads\\College_pitures\\BostonHousing_Expanded.csv")

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#          crim        zn     indus  chas       nox        rm        age  \
# 100  0.030599 -0.587372  7.305626   0.0  0.463584  7.163050  60.391619
# 101  0.030161  0.961950  2.144110   0.0  0.460461  7.070626  46.566272
# 102  0.030221  0.354590  7.154879   0.0  0.469622  6.431274  78.407092
# 103  0.025416  0.203895  6.912519   0.0  0.468375  7.148718  60.898630
# 104  0.033487  0.278732  2.469938   0.0  0.459754  6.989377  44.546559
#
#           dis       rad         tax    ptratio       black     lstat  \
# 100  5.003825  2.066128  242.393744  17.876366  393.022456  4.158766
# 101  6.070099  2.959075  223.050414  18.873753  394.558670  2.949824
# 102  4.985323  2.106786  240.111336  17.644663  397.040499  9.338961
# 103  5.057879  1.977022  243.003572  17.894268  392.804802  3.880662
# 104  6.107772  3.001070  226.330454  18.769942  394.713819  3.141168
#
#           medv
# 100  34.872554
# 101  33.920187
# 102  22.071153
# 103  34.199751
# 104  32.748525

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     105 non-null    float64
#  1   zn       105 non-null    float64
#  2   indus    105 non-null    float64
#  3   chas     105 non-null    float64
#  4   nox      105 non-null    float64
#  5   rm       105 non-null    float64
#  6   age      105 non-null    float64
#  7   dis      105 non-null    float64
#  8   rad      105 non-null    float64
#  9   tax      105 non-null    float64
#  10  ptratio  105 non-null    float64
#  11  black    105 non-null    float64
#  12  lstat    105 non-null    float64
#  13  medv     105 non-null    float64
# dtypes: float64(14)
# memory usage: 11.6 KB

# %%
df.describe()
# Out:
#              crim          zn       indus   chas         nox          rm  \
# count  105.000000  105.000000  105.000000  105.0  105.000000  105.000000
# mean     0.033736    2.281583    4.184107    0.0    0.472229    6.917368
# std      0.018387    5.960459    2.416044    0.0    0.025700    0.288661
# min      0.004178   -1.977497    1.717732    0.0    0.451752    6.385947
# 25%      0.026374   -0.262158    2.180000    0.0    0.458356    6.582340
# 50%      0.029994    0.160326    2.469938    0.0    0.464584    7.013969
# 75%      0.034109    0.639510    7.050882    0.0    0.469296    7.159960
# max      0.072075   18.690265    7.524842    0.0    0.542982    7.238788
#
#               age         dis         rad         tax     ptratio       black  \
# count  105.000000  105.000000  105.000000  105.000000  105.000000  105.000000
# mean    58.877382    5.383194    2.357747  239.304869   17.912959  395.298484
# ...

# %%
df.isnull()
# Out:
#       crim     zn  indus   chas    nox     rm    age    dis    rad    tax  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 100  False  False  False  False  False  False  False  False  False  False
# 101  False  False  False  False  False  False  False  False  False  False
# 102  False  False  False  False  False  False  False  False  False  False
# 103  False  False  False  False  False  False  False  False  False  False
# 104  False  False  False  False  False  False  False  False  False  False
#
#      ptratio  black  lstat   medv
# 0      False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
Q1 = df['medv'].quantile(0.25)
Q3 = df['medv'].quantile(0.75)
IQR = Q3 - Q1
Lower_limit = Q1 - 1.5 * IQR
Upper_limit = Q3 + 1.5 * IQR
print(f'Q1 = {Q1}, Q3 = {Q3}, IQR = {IQR}, Lower_limit = {Lower_limit},Upper_limit = {Upper_limit}')
# Out:
# Q1 = 24.18159926126485, Q3 = 35.051518816776905, IQR = 10.869919555512055, Lower_limit = 7.876719927996767,Upper_limit = 51.35639815004499

# %%
outliers_medv=[]
for i in df.medv:
  if i<Lower_limit or i>Upper_limit:
    outliers_medv.append(i)
    print("outliers are",outliers_medv)

# %%
X = df.drop(['medv'], axis = 1)
Y = df['medv']

# %%
X
# Out:
#          crim         zn     indus  chas       nox        rm        age  \
# 0    0.006320  18.000000  2.310000   0.0  0.538000  6.575000  65.200000
# 1    0.027310   0.000000  7.070000   0.0  0.469000  6.421000  78.900000
# 2    0.027290   0.000000  7.070000   0.0  0.469000  7.185000  61.100000
# 3    0.032370   0.000000  2.180000   0.0  0.458000  6.998000  45.800000
# 4    0.069050   0.000000  2.180000   0.0  0.458000  7.147000  54.200000
# ..        ...        ...       ...   ...       ...       ...        ...
# 100  0.030599  -0.587372  7.305626   0.0  0.463584  7.163050  60.391619
# 101  0.030161   0.961950  2.144110   0.0  0.460461  7.070626  46.566272
# 102  0.030221   0.354590  7.154879   0.0  0.469622  6.431274  78.407092
# 103  0.025416   0.203895  6.912519   0.0  0.468375  7.148718  60.898630
# 104  0.033487   0.278732  2.469938   0.0  0.459754  6.989377  44.546559
#
#           dis       rad         tax    ptratio       black     lstat
# ...

# %%
Y
# Out:
# 0      24.000000
# 1      21.600000
# 2      34.700000
# 3      33.400000
# 4      36.200000
#          ...
# 100    34.872554
# 101    33.920187
# 102    22.071153
# 103    34.199751
# 104    32.748525
# Name: medv, Length: 105, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
model = lm.fit(xtrain,ytrain)

# %%
model
# Out:
# LinearRegression()

# %%
ytrain_pred = lm.predict(xtrain)
ytest_pred = lm.predict(xtest)

# %%
xtest
# Out:
#          crim         zn     indus  chas       nox        rm        age  \
# 26   0.027708  -0.988496  7.050882   0.0  0.469522  6.435338  79.142066
# 61   0.032401   1.484865  1.945685   0.0  0.455679  7.013969  45.240322
# 2    0.027290   0.000000  7.070000   0.0  0.469000  7.185000  61.100000
# 62   0.070980  -1.977497  2.076563   0.0  0.460636  7.141004  54.126903
# 85   0.028059   0.006803  6.837130   0.0  0.467277  6.461755  78.890313
# 48   0.031610  -0.262158  2.453609   0.0  0.462020  7.020663  46.498423
# 16   0.031114   0.463181  2.468480   0.0  0.458405  6.983463  44.782558
# 100  0.030599  -0.587372  7.305626   0.0  0.463584  7.163050  60.391619
# 56   0.029994   0.192369  7.016518   0.0  0.471383  7.183574  61.788103
# 45   0.029313   0.834914  7.370602   0.0  0.464584  7.187292  60.433179
# 66   0.072075  -0.762432  2.566015   0.0  0.458328  7.154866  53.726737
# 97   0.030506  -0.791211  2.415397   0.0  0.460870  6.996419  46.848470
# ...

# %%
ytest
# Out:
# 26     20.852805
# 61     33.061442
# 2      34.700000
# 62     35.838358
# 85     21.242779
# 48     33.361327
# 16     34.075591
# 100    34.872554
# 56     35.592088
# 45     34.914681
# 66     35.734572
# 97     33.734177
# 51     33.590758
# 13     20.838912
# 7      33.896898
# 30     33.497476
# 22     33.662366
# 24     21.106916
# 33     35.398876
# 8      23.124846
# 43     23.428696
# Name: medv, dtype: float64

# %%
lm.predict(xtest.iloc[1].values.reshape(1, -1))
# Out:
# C:\Users\omkar\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([33.8087126])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred = lm.predict(xtest)

# %%
ytest.values
# Out:
# array([20.8528052 , 33.06144239, 34.7       , 35.83835767, 21.24277862,
#        33.36132745, 34.07559057, 34.87255376, 35.59208785, 34.91468117,
#        35.73457159, 33.73417721, 33.59075821, 20.83891225, 33.89689832,
#        33.49747647, 33.66236629, 21.10691562, 35.39887641, 23.12484583,
#        23.42869555])

# %%
print("MAE",mean_absolute_error(ytest,y_pred))
# Out:
# MAE 0.5570084021970516

# %%
print("MSE",mean_squared_error(ytest,y_pred))
# Out:
# MSE 0.4751774630526533

# %%
print("RMSE",np.sqrt(mean_absolute_error(ytest,y_pred)))
# Out:
# RMSE 0.7463299553126965

# %%
print("R2score",r2_score(ytest,y_pred))
# Out:
# R2score 0.98580841695402

# %%
import seaborn as sns
sns.regplot(x=ytest, y=ytest_pred, color='blue')
plt.show()
